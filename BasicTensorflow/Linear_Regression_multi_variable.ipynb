# %% [markdown]
# # multi-variable Linear Regression
# regression using three inputs (x1, x2, x3) <br>
# multi-variable/feature <br>
# **x1, x2, x2 and Y** <br>
# <br>
# <br>
# \\(H(x) = Wx + b\\)<br>
#
# \\(H(x_{1}, x_{2}, x_{3}) = W_{1}x_{1} + W_{2}x_{2} + W_{3}x_{3} + b\\)<hr><br>
# <br>
# \\(cost(W, b)\\) = \\(\frac{1}{m}\sum_{i=1}^{m} (H(x^i)-y^i)^2\\) <br>
# \\(cost(W, b)\\) = \\(\frac{1}{m}\sum_{i=1}^{m} H(x_{1}^{(i)}, x_{2}^{(i)}, x_{3}^{(i)})-y^{(i)})^2\\) <br>

# %% [markdown]
# ## Matrix
# ## 1. Matrix multiplication
# ## 2. Hypothesis using matrix
# \\(w_{1}x_{1}+w_{2}x_{2}+w_{3}x_{3}+ ... + w_{n}x_{n}\\)
# <br>
# \\((x_{1}, x_{2}, x_{3})
#  \begin{pmatrix}
#   w_{1} \\
#   w_{2} \\
#   w_{3} \\
#  \end{pmatrix}\\)
#  <br>
#  \\(H(X) = XW \\)
#  > matrix를 쓸 때는 보통 x를 앞에다 쓴다.
#
#  ### 1. Many x instances
#  데이터가 3개 <br>
#  많은 인스턴스들이 있을 때, <br>
#  * <u> 인스턴스가 만개일 때, </u> <br>
#  \\((x_{1}, x_{2}, x_{3})
#  \begin{pmatrix}
#   w_{1} \\
#   w_{2} \\
#   w_{3} \\
#  \end{pmatrix}\\)
#  <br>
#  이것을 만번 반복 <br><br>
#
#  * <u> 인스턴스 수대로 매트릭스를 준다. </u><br>
#  인스턴스가 5개 였을 경우, <br>
#  \\( \begin{pmatrix}
#   x_{11} x_{12} x{13} \\
#   x_{21} x_{22} x{23} \\
#   x_{31} x_{32} x{33} \\
#   x_{41} x_{42} x{43} \\
#   x_{51} x_{52} x{53} \\
#  \end{pmatrix} *
#  \begin{pmatrix}
#   w_{1} \\
#   w_{2} \\
#   w_{3} \\
#   w_{4} \\
#   w_{5} \\
#  \end{pmatrix}\\)
#  <br>
#  [5, 3] * [3, 1] = <br>\\([인스턴스 5개 * y의 variable의 갯수] * [데이터에 대한 weigt * 1]\\)<br>
#  \\([인스턴스 5개 * 3개의 x feature] * [데이터에 대한 weigt * 1]\\)
#  <br><br>
#  * =====인스턴스 갯수가 n개일 때 ===== <br>
#  numpy에서는 <br>
#  [-1, x의 feature]<br>
#  tensor에서는 <br>
#  [None, x의 feature]

# %%
import tensorflow as tf
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## \\(H(x1, x2, x3) = w_{1}x_{1}+w_{2}x_{2}+w_{3}x_{3}\\)

# %%
x1_data = [73., 93., 89., 96., 73.]
x2_data = [80., 88., 91., 98., 66.]
x3_data = [75., 93., 90., 100., 70.]

y_data = [152., 185., 180., 196., 142.]

x1 = tf.placeholder(tf.float32)
x2 = tf.placeholder(tf.float32)
x3 = tf.placeholder(tf.float32)

Y = tf.placeholder(tf.float32)

w1 = tf.Variable(tf.random_normal([1]), name='weight1')
w2 = tf.Variable(tf.random_normal([1]), name='weight2')
w3 = tf.Variable(tf.random_normal([1]), name='weight3')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = x1*w1 + x2*w2 + x3*w3 + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y)) # hyopothesis와 Y차이를 평균
optimizer = tf.train.GradientDescentOptimizer(learning_rate =1e-5)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                  feed_dict={x1: x1_data, x2: x2_data, x3: x3_data, Y: y_data})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nprediction:\n", hy_val)
# Out:
# 0 Cost:  27945.13
# prediction:
#  [8.049596  3.4288151 7.0267158 2.6177647 5.1811194]
# 10 Cost:  8.686878
# prediction:
#  [155.89769 181.1482  182.12775 193.30032 140.73888]
# 20 Cost:  8.402875
# prediction:
#  [156.33604 181.69202 182.65471 193.87608 141.1563 ]
# 30 Cost:  8.374708
# prediction:
#  [156.32838 181.69975 182.65343 193.87662 141.1648 ]
# 40 Cost:  8.34678
# prediction:
#  [156.31941 181.7058  182.65054 193.87541 141.17203]
# 50 Cost:  8.318964
# prediction:
#  [156.31044 181.71184 182.64766 193.87418 141.17921]
# 60 Cost:  8.29126
# prediction:
#  [156.3015  181.7179  182.64484 193.873   141.18642]
# 70 Cost:  8.263771
# prediction:
#  [156.2926  181.7239  182.64201 193.87183 141.1936 ]
# 80 Cost:  8.236389
# prediction:
#  [156.28372 181.72992 182.63918 193.87064 141.20074]
# 90 Cost:  8.2091465
# prediction:
#  [156.27487 181.73593 182.63635 193.86945 141.20789]
# 100 Cost:  8.1820135
# prediction:
#  [156.26602 181.74191 182.63354 193.86829 141.215  ]
# ...

# %% [markdown]
# ##  \\(H(X) = XW \\)

# %%
x_data = [[73., 80., 75.], # 하나의 인스턴스
          [93., 88., 93.],
          [89., 91., 90.],
          [96., 98., 100.],
          [73., 66., 70.]]
y_data = [[152.],
          [185.],
          [180.],
          [196.],
          [142.]]

X = tf.placeholder(tf.float32, shape=[None, 3]) # 인스턴스의 갯수, x의 features
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = tf.matmul(X, W) + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 1e-5)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 10 == 0:
        print(step, "Cost :", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost : 167586.56
# Prediction:
#  [[-199.47562]
#  [-260.01453]
#  [-245.44205]
#  [-271.3774 ]
#  [-199.93152]]
# 10 Cost : 63.72584
# Prediction:
#  [[162.56458]
#  [175.18861]
#  [183.34093]
#  [195.56041]
#  [132.03001]]
# 20 Cost : 61.86201
# Prediction:
#  [[163.62952]
#  [176.52625]
#  [184.62888]
#  [196.96687]
#  [133.0614 ]]
# 30 Cost : 61.533527
# Prediction:
#  [[163.60233]
#  [176.55112]
#  [184.62341]
#  [196.96486]
#  [133.0914 ]]
# 40 Cost : 61.20678
# Prediction:
#  [[163.57191]
#  [176.57191]
#  [184.61403]
#  [196.95853]
#  [133.11833]]
# 50 Cost : 60.881752
# Prediction:
#  [[163.54155]
#  [176.59265]
#  [184.60466]
#  [196.95222]
#  [133.14516]]
# 60 Cost : 60.55838
# Prediction:
#  [[163.51129]
#  [176.61337]
#  [184.59532]
#  [196.94597]
#  [133.17194]]
# 70 Cost : 60.236885
# Prediction:
#  [[163.48111]
#  [176.634  ]
#  [184.58603]
#  [196.93968]
#  [133.19864]]
# 80 Cost : 59.917095
# Prediction:
#  [[163.45099]
#  [176.65457]
#  [184.57672]
# ...

# %% [markdown]
# ##  파일에서 데이터 불러오기
# ### 1. numpy
# \\(H(X) = XW \\)<br>
# 출처: [Youtube 강의](https://www.youtube.com/watch?v=o2q4QNnoShY)<br>
# 출처: [DeepLearningZeroToAll](https://github.com/hunkim/DeepLearningZeroToAll/blob/master/lab-04-3-file_input_linear_regression.py)
# <br>
# 파일 : data-01-test-score.csv

# %%
import numpy as np

# %%
xy = np.loadtxt('data-01-test-score.csv', delimiter=',', dtype=np.float32)

print(xy)
# Out:
# [[ 73.  80.  75. 152.]
#  [ 93.  88.  93. 185.]
#  [ 89.  91.  90. 180.]
#  [ 96.  98. 100. 196.]
#  [ 73.  66.  70. 142.]
#  [ 53.  46.  55. 101.]
#  [ 69.  74.  77. 149.]
#  [ 47.  56.  60. 115.]
#  [ 87.  79.  90. 175.]
#  [ 79.  70.  88. 164.]
#  [ 69.  70.  73. 141.]
#  [ 70.  65.  74. 141.]
#  [ 93.  95.  91. 184.]
#  [ 79.  80.  73. 152.]
#  [ 70.  73.  78. 148.]
#  [ 93.  89.  96. 192.]
#  [ 78.  75.  68. 147.]
#  [ 81.  90.  93. 183.]
#  [ 88.  92.  86. 177.]
#  [ 78.  83.  77. 159.]
#  [ 82.  86.  90. 177.]
#  [ 86.  82.  89. 175.]
#  [ 78.  83.  85. 175.]
#  [ 76.  83.  71. 149.]
#  [ 96.  93.  95. 192.]]

# %%
# x와 y를 나누는 방법
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]

print(x_data)
print(y_data)
# Out:
# [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]
#  [ 69.  74.  77.]
#  [ 47.  56.  60.]
#  [ 87.  79.  90.]
#  [ 79.  70.  88.]
#  [ 69.  70.  73.]
#  [ 70.  65.  74.]
#  [ 93.  95.  91.]
#  [ 79.  80.  73.]
#  [ 70.  73.  78.]
#  [ 93.  89.  96.]
#  [ 78.  75.  68.]
#  [ 81.  90.  93.]
#  [ 88.  92.  86.]
#  [ 78.  83.  77.]
#  [ 82.  86.  90.]
#  [ 86.  82.  89.]
#  [ 78.  83.  85.]
#  [ 76.  83.  71.]
#  [ 96.  93.  95.]]
# [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]
#  [149.]
#  [115.]
#  [175.]
#  [164.]
#  [141.]
#  [141.]
#  [184.]
#  [152.]
#  [148.]
#  [192.]
#  [147.]
#  [183.]
#  [177.]
#  [159.]
#  [177.]
#  [175.]
#  [175.]
#  [149.]
#  [192.]]

# %%
print(x_data.shape, x_data, len(x_data))
print(y_data.shape, y_data)
# 인스턴스 25, x의 feature 3개
# Out:
# (25, 3) [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  90.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]
#  [ 53.  46.  55.]
#  [ 69.  74.  77.]
#  [ 47.  56.  60.]
#  [ 87.  79.  90.]
#  [ 79.  70.  88.]
#  [ 69.  70.  73.]
#  [ 70.  65.  74.]
#  [ 93.  95.  91.]
#  [ 79.  80.  73.]
#  [ 70.  73.  78.]
#  [ 93.  89.  96.]
#  [ 78.  75.  68.]
#  [ 81.  90.  93.]
#  [ 88.  92.  86.]
#  [ 78.  83.  77.]
#  [ 82.  86.  90.]
#  [ 86.  82.  89.]
#  [ 78.  83.  85.]
#  [ 76.  83.  71.]
#  [ 96.  93.  95.]] 25
# (25, 1) [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]
#  [101.]
#  [149.]
#  [115.]
#  [175.]
#  [164.]
#  [141.]
#  [141.]
#  [184.]
#  [152.]
#  [148.]
#  [192.]
#  [147.]
#  [183.]
#  [177.]
#  [159.]
#  [177.]
#  [175.]
#  [175.]
#  [149.]
#  [192.]]

# %%
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = tf.matmul(X, W) + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(2001):
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train],
        feed_dict={X: x_data, Y: y_data})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val,
                 "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  1464.5825
# Prediction:
#  [[123.5341  ]
#  [144.57669 ]
#  [144.90208 ]
#  [153.21376 ]
#  [112.95011 ]
#  [ 75.455666]
#  [108.73508 ]
#  [ 72.46868 ]
#  [128.45569 ]
#  [108.28846 ]
#  [108.315735]
#  [103.2307  ]
#  [154.42683 ]
#  [134.65988 ]
#  [108.12105 ]
#  [142.65567 ]
#  [132.61905 ]
#  [128.6123  ]
#  [148.55487 ]
#  [132.44482 ]
#  [128.6967  ]
#  [131.30522 ]
#  [124.34143 ]
#  [135.48903 ]
#  [152.6896  ]]
# 10 Cost:  121.74652
# Prediction:
#  [[157.70938]
#  [185.69327]
#  [185.39183]
#  [197.33371]
#  [144.299  ]
#  [ 98.60905]
#  [141.78389]
#  [ 97.00067]
#  [166.92035]
#  [143.97179]
#  [140.14462]
#  [134.64178]
#  [196.23495]
#  [169.38376]
#  [141.3305 ]
#  [184.39798]
#  [165.67314]
#  [168.27945]
#  [188.40286]
#  [168.0991 ]
#  [167.4492 ]
#  [169.89847]
#  [161.27869]
#  [169.89133]
#  [195.28464]]
# 20 Cost:  120.765945
# Prediction:
#  [[157.91513]
#  [185.98135]
#  [185.65274]
#  [197.64131]
#  [144.50946]
#  [ 98.8052 ]
#  [142.03763]
# ...

# %%
print("Your score will be ", sess.run(hypothesis,
                                     feed_dict={X: [[100, 70, 101]]}))
# Out:
# Your score will be  [[183.05507]]

# %% [markdown]
# 너의 final점수는 183일 것이다.

# %%
# 친구1과 친구2의 점수
print("Other scores will be ", sess.run(hypothesis, 
                                       feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# Other scores will be  [[139.53497]
#  [188.6085 ]]

# %% [markdown]
# ### 2. Queue Runners
# 파일이 굉장히 크면, 메모리에 한번에 올리는 것이 힘들다.
# **Queue Runners**는 하나의 파일이 아니라 여러개의 파일에서 읽어올 수 있다. <br>
# 학습을 시킬 때는 한번에 **전체 데이터**가 필요한 것이 **어떤 batch만큼** 읽어와서, 학습을 시킨다. <br>
# 참고: [Quere Runners](https://www.tensorflow.org/programmers_guide/datasets)
# 1. 파일 name을 리스트
# 우리가 가지고 있는 파일은 몇 개 인가?
# 2. 어떤 식으로 읽을지 정의
# 3. value를 읽어왔으면, value값을 어떻게 parsing할지 정의
# decode_csv

# %%
filename_queue = tf.train.string_input_producer(
    ['data-01-test-score.csv', 'data-02-test-score.csv', 'data-03-test-score.csv'],
    shuffle=False, name='filename_queue')
print(filename_queue)

# %%
reader = tf.TextLineReader()
key, value = reader.read(filename_queue)
print(key, value)
# Out:
# Tensor("ReaderReadV2_4:0", shape=(), dtype=string) Tensor("ReaderReadV2_4:1", shape=(), dtype=string)

# %%
record_defaults = [[0.], [0.], [0.], [0.]]
xy = tf.decode_csv(value, record_defaults=record_defaults)
print(xy)
# Out:
# [<tf.Tensor 'DecodeCSV_1:0' shape=() dtype=float32>, <tf.Tensor 'DecodeCSV_1:1' shape=() dtype=float32>, <tf.Tensor 'DecodeCSV_1:2' shape=() dtype=float32>, <tf.Tensor 'DecodeCSV_1:3' shape=() dtype=float32>]

# %%
train_x_batch, train_y_batch = \
    tf.train.batch([xy[0:-1], xy[-1:]], batch_size=10)
print(train_x_batch)
print(train_y_batch)
X = tf.placeholder(tf.float32, shape=[None, 3])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = tf.matmul(X, W) + b
# Out:
# Tensor("batch_5:0", shape=(10, 3), dtype=float32)
# Tensor("batch_5:1", shape=(10, 1), dtype=float32)

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
sess = tf.Session(), 
sess.run(tf.global_variables_initializer())

# %%
coord = tf.train.Coordinator()
threads = tf.train.start_queue_runners(sess=sess, coord=coord)

for step in range(2001):
    x_batch, y_batch = sess.run([train_x_batch, train_y_batch])
    cost_val, hy_val, _ = sess.run(
        [cost, hypothesis, train], feed_dict={X: x_batch, Y: y_batch})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction\n", hy_val)
# Out:
# 0 Cost:  9559.545
# Prediction
#  [[79.46881 ]
#  [58.758198]
#  [83.29903 ]
#  [87.19789 ]
#  [67.44292 ]
#  [51.631832]
#  [82.46264 ]
#  [60.319237]
#  [52.64154 ]
#  [77.03049 ]]
# 10 Cost:  94.60923
# Prediction
#  [[138.51463]
#  [173.59554]
#  [166.26059]
#  [147.43486]
#  [173.00954]
#  [179.40239]
#  [162.29413]
#  [134.11436]
#  [190.70679]
#  [141.20366]]
# 20 Cost:  83.40703
# Prediction
#  [[139.18588]
#  [174.37265]
#  [167.07236]
#  [148.16646]
#  [173.75562]
#  [180.11807]
#  [163.01537]
#  [134.85161]
#  [191.52454]
#  [141.90546]]
# 30 Cost:  82.71179
# Prediction
#  [[139.225  ]
#  [174.39395]
#  [167.12292]
#  [148.21693]
#  [173.76323]
#  [180.09848]
#  [163.03246]
#  [134.93059]
#  [191.52974]
#  [141.95464]]
# 40 Cost:  82.090225
# Prediction
#  [[139.25963]
#  [174.41002]
#  [167.16806]
#  [148.26254]
#  [173.7658 ]
#  [180.07393]
#  [163.0447 ]
#  [135.00471]
#  [191.52937]
#  [141.99913]]
# 50 Cost:  81.474815
# Prediction
#  [[139.29399]
#  [174.426  ]
# ...

# %%
print("Your score will be ",
      sess.run(hypothesis, feed_dict={X: [[100, 70, 101]]}))

print("Other scores will be ",
      sess.run(hypothesis, feed_dict={X: [[60, 70, 110], [90, 100, 80]]}))
# Out:
# Your score will be  [[207.63976]]
# Other scores will be  [[187.09529]
#  [167.10846]]

# %% [markdown]
# Shuffle_batch?
